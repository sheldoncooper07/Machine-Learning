# %% [markdown]
# <a href="https://colab.research.google.com/github/sheldoncooper07/Machine-Learning/blob/master/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("http://13.234.66.67/summer19/datasets/diabetest.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
import seaborn as sb

# %%
#plot a particular column with count
sb.countplot(df['Pregnancies'])

# %%
df.hist(figsize=(15,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc83ad828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc5aa2358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc5a4b898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc5a73e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc5a233c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc59cb940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc59f3eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc59a44a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc59a44e0>]],
#       dtype=object)

# %%
sb.scatterplot(df['Pregnancies'],df['Glucose'])

# %%
sb.pairplot(df)

# %%
features=df.iloc[:,0:8].values

# %%
label=df.iloc[:,8].values

# %%
from sklearn.model_selection import train_test_split
X,x,Y,y=train_test_split(features,label,test_size=0.2) 
# X= train data x=test dat Y=train ans y=test ans

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
trained=clf.fit(X,Y)

# %%
y_predict=trained.predict(x)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y,y_predict)
# Out:
# 0.7012987012987013

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kclf=KNeighborsClassifier(n_neighbors=5)

# %%
kt=kclf.fit(X,Y)

# %%
out1=kt.predict(x)

# %%
accuracy_score(y,out1)
# Out:
# 0.7337662337662337
