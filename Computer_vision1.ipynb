# %% [markdown]
# <a href="https://colab.research.google.com/github/sheldoncooper07/Machine-Learning/blob/master/Computer_vision1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
image1=cv2.imread('Sunset1.jpg')
image2=cv2.imread('Sunset2.jpg')
image3=cv2.imread('Sunset3.jpg')
image=image1

# %%
image3.shape
# Out:
# (225, 225, 3)

# %%
image2.shape
# Out:
# (400, 500, 3)

# %%
#resizing image2 to become equal to image1
image1 = cv2.resize(image1,(500,400), interpolation = cv2.INTER_AREA) 
image2 = cv2.resize(image2,(500,400), interpolation = cv2.INTER_AREA)

# %%
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400 at 0x7F0D2C19EB00>

# %%
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400 at 0x7F0D2B928C50>

# %%
#Now cropping image1 and image2
crop_img1=image1[0:250,0:350]
crop_img2=image2[0:250,0:350]

# %%
cv2_imshow(crop_img1)
cv2_imshow(crop_img2)
# Out:
# <PIL.Image.Image image mode=RGB size=350x250 at 0x7F0D2B928D68>
# <PIL.Image.Image image mode=RGB size=350x250 at 0x7F0D2B928DA0>

# %%
crop_img1[55:90,55:90]=image2[55:90,55:90]
crop_img2[55:90,55:90]=image[55:90,55:90]

# %%
cv2_imshow(crop_img1)
cv2_imshow(crop_img2)
# Out:
# <PIL.Image.Image image mode=RGB size=350x250 at 0x7F0D2B928BE0>
# <PIL.Image.Image image mode=RGB size=350x250 at 0x7F0D2B928F28>

# %%
a = np.arange(600).reshape(10,20,3)
a[0:10,0:20]=image1[0:10,0:20]
image1[0:10,0:20]=image3[0:10,0:20]
image3[0:10,0:20]=a[0:10,0:20]

# %%
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400 at 0x7F0D2B928B00>

# %%
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400 at 0x7F0D2C28C940>
