# %% [markdown]
# <a href="https://colab.research.google.com/github/sheldoncooper07/Machine-Learning/blob/master/images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
img=cv2.imread('a.jpg',1)
img1=cv2.imread('a.jpg',0)
#1 means pic show original color
#0 means black and white

# %%
img
# Out:
# array([[[11,  6,  8],
#         [11,  6,  8],
#         [11,  6,  8],
#         ...,
#         [ 3,  3,  3],
#         [ 3,  3,  3],
#         [ 3,  3,  3]],
#
#        [[11,  6,  8],
#         [11,  6,  8],
#         [11,  6,  8],
#         ...,
#         [ 3,  3,  3],
#         [ 3,  3,  3],
#         [ 3,  3,  3]],
#
#        [[11,  6,  8],
#         [11,  6,  8],
#         [11,  6,  8],
#         ...,
#         [ 3,  3,  3],
#         [ 3,  3,  3],
#         [ 3,  3,  3]],
#
#        ...,
#
#        [[13,  7, 12],
#         [13,  7, 12],
#         [13,  7, 12],
#         ...,
#         [19, 17, 17],
#         [20, 18, 18],
#         [20, 18, 18]],
#
#        [[13,  7, 12],
#         [13,  7, 12],
#         [13,  7, 12],
#         ...,
#         [21, 19, 19],
#         [22, 20, 20],
#         [22, 20, 20]],
#
#        [[13,  7, 12],
#         [13,  7, 12],
#         [13,  7, 12],
#         ...,
#         [23, 21, 21],
#         [24, 22, 22],
#         [25, 23, 23]]], dtype=uint8)

# %%
#img.shape

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#to display image
#cv2.imshow('a',img)
#wait for windows to close
#cv2.waitKey()
plt.imshow(img)

# %%
plt.imshow(img1)

# %%
plt.imshow(img1[0:130,0:150])

# %%
#split into BGR 
x,y,z=cv2.split(img)

# %%
plt.imshow(x)

# %%
plt.imshow(y)

# %%
plt.imshow(z)

# %%
import numpy as np

# %%
#to draw a line
cv2.line(img,(0,0),(150,160),(0,0,255),(3))
cv2.rectangle(img,(50,50),(150,150),(0,0,255),(3))
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        ...,
#
#        [[ 13,   7,  12],
#         [ 13,   7,  12],
#         [ 13,   7,  12],
#         ...,
#         [ 19,  17,  17],
#         [ 20,  18,  18],
#         [ 20,  18,  18]],
#
#        [[ 13,   7,  12],
#         [ 13,   7,  12],
#         [ 13,   7,  12],
#         ...,
#         [ 21,  19,  19],
#         [ 22,  20,  20],
#         [ 22,  20,  20]],
#
#        [[ 13,   7,  12],
#         [ 13,   7,  12],
#         [ 13,   7,  12],
# ...

# %%
plt.imshow(img)

# %%
plt.imshow(img-100)

# %%
plt.imshow(img+100)

# %%
plt.imshow(img%2)

# %%
plt.imshow(img[0:150,0:50]+100)
